# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='Outcome', y='Insulin', data=df)
plt.title('Insulin by Outcome')
plt.show()

sns.boxplot(x='Outcome', y='BloodPressure', data=df)
plt.title('BloodPressure by Outcome')
plt.show()
sns.boxplot(x='Outcome', y='SkinThickness', data=df)
plt.title('Skin Thickness by Outcome')
plt.show()

# %%
cols_with_zeros = ['BloodPressure', 'SkinThickness', 'Insulin','Glucose','BMI']

for col in cols_with_zeros:
    df[col] = df.groupby('Outcome')[col].transform(
        lambda x: x.mask(x == 0, x[x != 0].median())
    )

# %%
df['Insulin'] = df.groupby('Outcome')['Insulin'].transform(
    lambda x: x.replace(0, x.median())
)
df['SkinThickness'] = df.groupby('Outcome')['SkinThickness'].transform(
    lambda x: x.replace(0, x.median())
)
df['BloodPressure'] = df.groupby('Outcome')['BloodPressure'].transform(
    lambda x: x.replace(0, x.median())
)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148           72.0             35    169.5  33.6
# 1              1       85           66.0             29    102.5  26.6
# 2              8      183           64.0             32    169.5  23.3
# 3              1       89           66.0             23     94.0  28.1
# 4              0      137           40.0             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48    180.0  32.9
# 764            2      122           70.0             27    102.5  36.8
# 765            5      121           72.0             23    112.0  26.2
# 766            1      126           60.0             32    169.5  30.1
# 767            1       93           70.0             31    102.5  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print(df.groupby('Outcome')['Insulin'].median())
# Out:
# Outcome
# 0    102.5
# 1    169.5
# Name: Insulin, dtype: float64

# %%
(df == 0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                     500
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

# %%
from sklearn.model_selection import train_test_split
x = df.drop('Outcome', axis=1)
y = df['Outcome']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
x_train = std.fit_transform(x_train)
x_test = std.transform(x_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.3)),
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3)),
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Diabetes\.venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.utils import class_weight
from keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Compute class weights
weights = class_weight.compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weights = {i: weights[i] for i in range(len(weights))}

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(x_train, y_train, epochs=30, batch_size=16, class_weight=class_weights, verbose=1, validation_split=0.1,callbacks=[early_stop])

# Predict
y_pred = (model.predict(x_test) > 0.6).astype("int32")

# Evaluate
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5460 - loss: 0.6766 - val_accuracy: 0.7581 - val_loss: 0.5987
# Epoch 2/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7487 - loss: 0.5653 - val_accuracy: 0.7419 - val_loss: 0.5299
# Epoch 3/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7760 - loss: 0.4975 - val_accuracy: 0.7419 - val_loss: 0.4991
# Epoch 4/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7668 - loss: 0.4690 - val_accuracy: 0.7419 - val_loss: 0.4818
# Epoch 5/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7993 - loss: 0.4542 - val_accuracy: 0.7581 - val_loss: 0.4644
# Epoch 6/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8088 - loss: 0.4455 - val_accuracy: 0.7581 - val_loss: 0.4620
# Epoch 7/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7781 - loss: 0.4604 - val_accuracy: 0.7581 - val_loss: 0.4520
# Epoch 8/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8298 - loss: 0.4213 - val_accuracy: 0.7581 - val_loss: 0.4427
# Epoch 9/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7901 - loss: 0.4611 - val_accuracy: 0.7581 - val_loss: 0.4305
# Epoch 10/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8065 - loss: 0.4764 - val_accuracy: 0.7742 - val_loss: 0.4304
# Epoch 11/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7933 - loss: 0.4838 - val_accuracy: 0.7903 - val_loss: 0.4180
# Epoch 12/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8198 - loss: 0.4293 - val_accuracy: 0.8065 - val_loss: 0.4099
# Epoch 13/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4136 - val_accuracy: 0.8226 - val_loss: 0.4040
# Epoch 14/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8255 - loss: 0.4097 - val_accuracy: 0.8065 - val_loss: 0.4020
# Epoch 15/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8013 - loss: 0.4064 - val_accuracy: 0.8065 - val_loss: 0.3905
# Epoch 16/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8270 - loss: 0.4040 - val_accuracy: 0.8226 - val_loss: 0.3749
# Epoch 17/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8415 - loss: 0.3860 - val_accuracy: 0.8387 - val_loss: 0.3645
# Epoch 18/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8487 - loss: 0.3523 - val_accuracy: 0.8387 - val_loss: 0.3624
# Epoch 19/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8195 - loss: 0.4091 - val_accuracy: 0.8387 - val_loss: 0.3521
# Epoch 20/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8310 - loss: 0.3560 - val_accuracy: 0.8387 - val_loss: 0.3485
# Epoch 21/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8285 - loss: 0.3855 - val_accuracy: 0.8548 - val_loss: 0.3488
# Epoch 22/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8520 - loss: 0.3615 - val_accuracy: 0.8548 - val_loss: 0.3212
# Epoch 23/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8620 - loss: 0.3792 - val_accuracy: 0.8710 - val_loss: 0.3277
# Epoch 24/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8347 - loss: 0.3695 - val_accuracy: 0.8871 - val_loss: 0.3181
# Epoch 25/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8445 - loss: 0.3926 - val_accuracy: 0.8871 - val_loss: 0.3203
# Epoch 26/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8670 - loss: 0.3256 - val_accuracy: 0.8871 - val_loss: 0.3107
# Epoch 27/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8666 - loss: 0.3472 - val_accuracy: 0.8871 - val_loss: 0.3006
# Epoch 28/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8512 - loss: 0.3292 - val_accuracy: 0.8710 - val_loss: 0.3106
# Epoch 29/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8728 - loss: 0.3029 - val_accuracy: 0.8871 - val_loss: 0.2989
# Epoch 30/30
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8524 - loss: 0.4168 - val_accuracy: 0.8710 - val_loss: 0.3025
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87        99
#            1       0.73      0.85      0.79        55
#
#     accuracy                           0.84       154
#    macro avg       0.82      0.84      0.83       154
# weighted avg       0.85      0.84      0.84       154

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc:.4f}")
# Out:
# Accuracy: 0.8377

# %%
model.save('final_model_acc86.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
